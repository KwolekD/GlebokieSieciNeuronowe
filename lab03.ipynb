# %% [markdown]
# # Wstęp
#
# Na poprzednich zajęciach nauczyłeś(aś) się jak skonstruować od zera podstawową komórkę sieci neuronowej - Perceptron. Na tych zajęciach przejdziemy już do wykorzystywania bardziej zaawansowanych funkcji PyTorcha, które przydają się na codzień do konstruowania sieci neuronowych.
#
# ## Cel ćwiczenia
#
# Celem ćwiczenia jest zapoznanie z podstawowymi funkcjami biblioteki PyTorch do tworzenia i uczenia sieci neuronowych a w szczególności z:
# *   Automatycznym liczeniem gradientów i grafem obliczeniowym (autograd)
# *   Algorytmami off-line, on-line a także pojęciem mini-batch
# *   Algorytmami optymalizacji sieci neuronowych
# *   Liczeniem wartości fuknkcji straty
# *   Przekształceniami nieliniowymi
# *   Modułem `torch.nn`
#
# ## Warunki zaliczenia
#
# W celu zaliczenia ćwiczeń należy uzupełnić wszystkie brakujące elementu kodu, wykonać wszystkie polecenia i wyuczyć model.

# %%
import math
import warnings
from typing import Tuple

import torch
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from torch import nn
from torch import optim
from torch.utils.data import TensorDataset, DataLoader

assert torch.cuda.is_available(), "Uruchom środowisko wykonawcze na GPU"

# %% [markdown]
# # Autograd - automatyczne liczenie gradientów
#
# Na poprzednich laboratoriach implementowałeś(aś) funkcję wstecznej propagacji. W tym celu liczyłaś(eś) pochodne (gradienty). Przyjrzyjmy się najpierw funkcji
# $$f(x, y) = 3x^2 + y^3$$
# Możemy tę funkcję różniczkować po dwóch zmiennych: $x$ i $y$:
# $$\frac{\partial f}{\partial x} = 6x$$
#
# $$\frac{\partial f}{\partial y} = 3y^2$$
#
# Jeżeli funkcję $f(x,y)$ złożymy z funkcją $g(x) = x^2$ tworząc funkcję $h(x, y) = f(g(x), y)$ to z **reguły łańcuchowej** pochodna takiej funkcji wyniesie:
#
# $$\frac{\partial h}{\partial x} = \frac{\partial f}{\partial g} \frac{\partial g}{\partial x} = (6 (x^2)) (2 x) = 12 x^3$$
#
# Tego typu obliczenia przy wielu warstwach sieci (a więc przy wielu złożeniach funkcji liniowych i nieliniowych) stają się mocno skomplikowane. Na szczęście PyToch dostarcza `torch.autograd` - silnik do zaumatyzowanego liczenia gradientów. Jak on działa? Najpierw zdefiniujmy wektory $\mathbf x$ i $\mathbf y$.

# %%
x = torch.tensor([0., 1., 5.], requires_grad=True)
y = torch.tensor([8., 2., 4.], requires_grad=True)

# %% [markdown]
# Zauważ, że tworząc tensor przekazaliśmy parametr `requires_grad=True`. Sprawia on, że wszystkie operacje dokonane na tym tensorze są śledzone i tensor wynikowy będzie "pamiętał" przy użyciu jakiej operacji powstał. Policzmy naszą funkcję $f( \mathbf x, \mathbf y)$ dla tych tensorów.

# %%
z = 3*x**2 + y**3
z
# Out:
# tensor([512.,  11., 139.], grad_fn=<AddBackward0>)

# %% [markdown]
# Jak widać uzyskany tensor ma także zapisany parametr `grad_fn=<AddBackward0>`, czyli że powstał z dodania dwóch tensorów - dodawanie jest ostatnią operacją, która zostałą wykonana, żeby otrzymać ten tensor. Dokonajmy propagacji wstecznej w celu policzenia gradientów.

# %%
grad_tensors = torch.tensor([1., 1., 1.])
z.backward(grad_tensors)
print(x.grad == 6*x)
print(y.grad == 3*y**2)
# Out:
# tensor([True, True, True])
# tensor([True, True, True])

# %% [markdown]
# Na razie nie przejmuj się tym za co odpowiada `grad_tensors`. Policzmy wartość funkcji $h$.

# %%
a = 3*(x**2)**2 + y**3
a.backward(grad_tensors)
print(x.grad)
print(12*(x**3))
print(x.grad == 12*(x**3))
# Out:
# tensor([   0.,   18., 1530.])
# tensor([   0.,   12., 1500.], grad_fn=<MulBackward0>)
# tensor([ True, False, False])

# %% [markdown]
# Nie zgadzają nam się wartości. Wynika to z kolejnej właśności pytorchowego autograda - gradienty w tensorach są **akumulowane**. Jak wykonasz powyższą komórkę wielekrotnie to zobaczysz że wartości `x.grad` rosną dokładnie o $12x_i^3$ po każdym wykonaniu. Akumulacja gradientów jest przydatna w niektórych architekturach sieci neuronowych. Dlatego też trzeba *explicite* wyzerować gradienty.

# %%
x.grad.data.zero_()
a = 3*(x**2)**2 + y**3
a.backward(grad_tensors)
print(x.grad)
print(12*(x**3))
assert (x.grad == 12*(x**3)).all()
# Out:
# tensor([   0.,   12., 1500.])
# tensor([   0.,   12., 1500.], grad_fn=<MulBackward0>)

# %% [markdown]
# Ok, powróćmy teraz do `grad_tensors` - co to jest? Otóż autograd jest silnikiem, który służy do wyliczania **macierzy Jacobiego**, tj. pochodnych pierwszego rzędu funkcji, których składowymi są funkcje rzeczywiste.
#
# $$f = (f_1, f_2, \ldots, f_m)$$
# $$\mathbf x = (x_1, x_2, \ldots, x_n)$$
#
# $$\mathbf J = \begin{bmatrix}
#  \dfrac{\partial f_1}{\partial x_1} & \cdots & \dfrac{\partial f_1}{\partial x_n} \\
#  \vdots & \ddots & \vdots \\
#  \dfrac{\partial f_m}{\partial x_1} & \cdots & \dfrac{\partial f_m}{\partial x_n}
# \end{bmatrix}$$
#
# Konkretnie patrząc na przykład z tensorem $a$ macierz Jacobiego wygląda tak:
# $$\mathbf J_a = \begin{bmatrix}
#  \dfrac{\partial a_1}{\partial x_1} & \dfrac{\partial a_1}{\partial x_2} & \dfrac{\partial a_1}{\partial x_3} \\
#   \dfrac{\partial a_2}{\partial x_1} & \dfrac{\partial a_2}{\partial x_2} & \dfrac{\partial a_2}{\partial x_3} \\
#    \dfrac{\partial a_3}{\partial x_1} & \dfrac{\partial a_3}{\partial x_2} & \dfrac{\partial a_3}{\partial x_3} \\
# \end{bmatrix}$$
#
# Następnie `grad_tensors` ($\mathbf z$) mnożymy przez transpozycję tej macierzy (ang. *Jacobian-vector product*).
#
# $$ \mathbf z \mathbf J_a^T = \begin{bmatrix} 1 & 1 & 1 \end{bmatrix}
# \begin{bmatrix}
#  \dfrac{\partial a_1}{\partial x_1} & \dfrac{\partial a_2}{\partial x_1} & \dfrac{\partial a_3}{\partial x_1} \\
#   \dfrac{\partial a_1}{\partial x_2} & \dfrac{\partial a_2}{\partial x_2} & \dfrac{\partial a_3}{\partial x_2} \\
#    \dfrac{\partial a_1}{\partial x_3} & \dfrac{\partial a_2}{\partial x_3} & \dfrac{\partial a_3}{\partial x_3} \\
# \end{bmatrix}
# = \begin{bmatrix} 1\dfrac{\partial a_1}{\partial x_1} + 1\dfrac{\partial a_1}{\partial x_2} + 1\dfrac{\partial a_1}{\partial x_3} & 1\dfrac{\partial a_2}{\partial x_1} + 1\dfrac{\partial a_2}{\partial x_2} + 1\dfrac{\partial a_2}{\partial x_3} & 1\dfrac{\partial a_3}{\partial x_1} + 1\dfrac{\partial a_3}{\partial x_2} + 1\dfrac{\partial a_3}{\partial x_3} \end{bmatrix}
# = \begin{bmatrix} 12(0)^3 + 0 + 0 & 0 + 12(1)^3 + 0 & 0 + 0 + 12(5)^3 \end{bmatrix} =  \begin{bmatrix} 0 & 12 & 1500 \end{bmatrix}$$
#
# Uzyskujemy te same gradienty co policzyliśmy dla wektora $\mathbf x$. Zamiast przekazywać wektor jedynek do `backward()`, można najpierw policzyć sumę wektora $\mathbf a$ a potem wykonać propagację wsteczną.

# %%
x.grad.data.zero_()
a = 3*(x**2)**2 + y**3
a.sum().backward()
print(x.grad)
print(12*(x**3))
assert (x.grad == 12*(x**3)).all()
# Out:
# tensor([   0.,   12., 1500.])
# tensor([   0.,   12., 1500.], grad_fn=<MulBackward0>)

# %% [markdown]
# Wtedy pamiętając o tym, że pochodna sumy to suma pochodnych ($(f(x) + g(x))' = f'(x) + g'(x)$):
#
# $$\begin{bmatrix}
#  \dfrac{\partial a}{\partial x_1} & \dfrac{\partial a}{\partial x_2} & \dfrac{\partial a}{\partial x_3}
# \end{bmatrix} = \begin{bmatrix} \dfrac{\partial (a_1 + a_2 + a_3)}{\partial x_1} & \dfrac{\partial (a_1 + a_2 + a_3)}{\partial x_2} & \dfrac{\partial (a_1 + a_2 + a_3)}{\partial x_3} \end{bmatrix} = \begin{bmatrix} \dfrac{\partial a_1}{\partial x_1} + \dfrac{\partial a_2}{\partial x_1} + \dfrac{\partial a_3}{\partial x_1} & \dfrac{\partial a_1}{\partial x_2} + \dfrac{\partial a_2}{\partial x_2} + \dfrac{\partial a_3}{\partial x_2} & \dfrac{\partial a_1}{\partial x_3} + \dfrac{\partial a_2}{\partial x_3} + \dfrac{\partial a_3}{\partial x_3} \end{bmatrix} = \begin{bmatrix} \dfrac{\partial a_1}{\partial x_1} & \dfrac{\partial a_2}{\partial x_2} & \dfrac{\partial a_3}{\partial x_3} \end{bmatrix} =  \begin{bmatrix} 0 & 12 & 1500 \end{bmatrix} $$
#
# Zatem po co w ogóle ten wektor? Otóż służy on do przekazywania wektora gradientu funkcji straty ($\dfrac{\partial \mathbf{loss}}{\partial \mathbf y}$) lub "warstwy" wcześniejszej w obliczenich ($\dfrac{\partial \mathbf{f}}{\partial \mathbf y}$). Przeanalizumy to na przykładzie z funkcjami $f$, $g$, i $h$, które zaprezentowaliśmy wcześniej omawiając regułę łańcuchową.

# %%
x = torch.tensor([0., 1., 5.], requires_grad=True)
y = torch.tensor([8., 2., 4.], requires_grad=True)

g = x**2
h = 3*g**2 + y**3
g.retain_grad()
h.retain_grad()

h.sum().backward()
h_grad = h.grad
g_grad = g.grad
h.grad, g.grad, x.grad, y.grad
# Out:
# (tensor([1., 1., 1.]),
#  tensor([  0.,   6., 150.]),
#  tensor([   0.,   12., 1500.]),
#  tensor([192.,  12.,  48.]))

# %% [markdown]
# Wykorzystaliśmy `retain_grad()`, żeby zapamiętać gradienty w tensorach pośrednich - domyślnie PyTorch nie zapamiętuje tych gradientów, aby [oszczędzić pamięć](https://discuss.pytorch.org/t/why-cant-i-see-grad-of-an-intermediate-variable/94/2). Zauważ, że:
#
#
# *   `h.grad` zawiera wektor jedynek;
# *   `g.grad` zawiera wartości pochodnej funkcji $f$ ($\frac{\partial f}{\partial x} = 6$);
# *   `x.grad` zawiera wartości pochodnej funkcji $h$ ($\frac{\partial h}{\partial x} = 12x^3$)
# *   `y.grad` zawiera wartości pochodnej funkcji $h$ ($\frac{\partial h}{\partial y} = \frac{\partial f}{\partial y} = 3y^2$).
#
# To teraz somodzielnie oddtworzymy działanie funkcji `backward()` wykrozystując gradienty pośrednie z wektorów $\mathbf g$ i $\mathbf h$.

# %%
x = torch.tensor([0., 1., 5.], requires_grad=True)
y = torch.tensor([8., 2., 4.], requires_grad=True)

g = x**2
h = 3*g**2 + y**3
g.retain_grad()
h.retain_grad()

h.backward(h_grad)
# h.sum().backward()
h.grad, g.grad, x.grad, y.grad
# Out:
# (tensor([1., 1., 1.]),
#  tensor([  0.,   6., 150.]),
#  tensor([   0.,   12., 1500.]),
#  tensor([192.,  12.,  48.]))

# %%
x = torch.tensor([0., 1., 5.], requires_grad=True)
y = torch.tensor([8., 2., 4.], requires_grad=True)

g = x**2
h = 3*g**2 + y**3
g.retain_grad()
h.retain_grad()

g.backward(g_grad)
# h.backward(h_grad)
# h.sum().backward()
h.grad, g.grad, x.grad, y.grad
# Out:
# (None, tensor([  0.,   6., 150.]), tensor([   0.,   12., 1500.]), None)

# %% [markdown]
# Jak widać uzyskaliśmy te same gradienty wektora $\mathbf x$ przechodząc po grafie obliczeń "ręcznie" oraz przekazując odpowiednie gradienty w parametrze `grad_tensors`. No właśnie, wspomnieliśmy "graf obliczeń" - o co chodzi?

# %% [markdown]
# ## Graf obliczeniowy
#
# To wszystko jest możliwe dzięki temu, że autograd tworzy **acykliczny skierowany graf obilczeniowy**. Gdzie go przechowuje? Spójrzmy jeszcze raz na nasz wektor $\mathbf a$.

# %%
print(a)
print(a.grad_fn.next_functions)
# Out:
# tensor([ 512.,   11., 1939.], grad_fn=<AddBackward0>)
# ((<MulBackward0 object at 0x7edd603c17e0>, 0), (<PowBackward0 object at 0x7edeec105450>, 0))

# %% [markdown]
# Obiekt a ma pole `grad_fn` a ono ma pole `next_functions`. Widzimy, że $\mathbf a$ powstało z przemnożenia dwóch tensorów, gdzie pierwszy tensor był wynikiem mnożenia a drugi - potęgowania. A więc na razie wiemy, że `a = (_*_) + (_**_)`. I kolejno przechodząc po tym grafie możemy dalej odkrywać jego strukturę i jaka droga skonstruowania $\mathbf a$ się za nim kryje.

# %%
print(a.grad_fn.next_functions[0][0].next_functions) # a = ((_**_))*_) + (_**_)
print(a.grad_fn.next_functions[0][0].next_functions[0][0].next_functions) # a = (((_**_))**_))*_) + (_**_)
print(a.grad_fn.next_functions[0][0].next_functions[0][0].next_functions[0][0].next_functions) # a = (((x**_))**_))*_) + (_**_)
print()
print(a.grad_fn.next_functions[1][0].next_functions) # a = (((x**_))**_))*_) + (y**_)
# Out:
# ((<PowBackward0 object at 0x7edd55243460>, 0), (None, 0))
# ((<PowBackward0 object at 0x7edd552439d0>, 0),)
# ((<AccumulateGrad object at 0x7edd55243460>, 0),)
#
# ((<AccumulateGrad object at 0x7edd552439d0>, 0),)

# %% [markdown]
# Po chwilii analizy można dostrzec że ta strutura odpowiada obliczeniu tensora $a$ ze wzoru $3(\mathbf x^2)^2 + \mathbf y^3$.
#
# Jeszcze warto wspomnieć o tym, że PyTorch śledzi to dla których tensorów trzeba tworzyć ten graf a dla których nie. Dlatego też jeżeli w operacjach użyjemy tensora, który "wymaga gradientu" (`requires_grad=True`) to uzyskamy tensor "wymagający gradientu":

# %%
x = torch.tensor([1., 2., 3.])
y = torch.tensor([6., 7., 8.])
z = torch.tensor([9., 7., 8.], requires_grad=True)
print((2*x + 3**y).requires_grad)
print((2*x + 3**y + z).requires_grad)
# Out:
# False
# True

# %% [markdown]
# Dla chcących dowiedzieć się czegoś więcej o mechanizmach autograda polecamy: [1](https://www.cs.toronto.edu/~rgrosse/courses/csc321_2018/slides/lec10.pdf), [2](https://github.com/mattjj/autodidact/).

# %% [markdown]
# # Refatoring kodu z laboratorium 2
#
# W tej części laboratorium dokonasz refaktoringu kodu z laboratorium drugiego z wykorzystaniem gotowych rozwiązań w bibliotece `torch` a w szczególności w `torch.nn`. Najpierw zacznijmy od załadowania zbioru danych i podzielenia go na zbiór uczący i testowy.

# %%
X, y = load_iris(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1, stratify=y)

X_train = torch.tensor(X_train).float().cuda()
X_test = torch.tensor(X_test).float().cuda()
y_train = torch.tensor(y_train).cuda()
y_test = torch.tensor(y_test).cuda()

y_test
# Out:
# tensor([0, 2, 0, 1, 2, 1, 1, 2, 2, 0, 2, 0, 2, 2, 1, 1, 2, 1, 2, 1, 0, 0, 2, 0,
#         1, 1, 2, 0, 2, 0, 0, 1, 1, 2, 2, 0, 0, 0, 0, 2, 1, 2, 0, 0, 2, 2, 1, 0,
#         0, 1, 2, 1, 1, 1, 2, 1, 0, 0, 1, 1], device='cuda:0')

# %% [markdown]
# ## `nn.Module` oraz `CrossEntropyLoss`
#
# Na poprzednich laboratoriach w tym miejscu implementowaliśmy funkcję sigmoid, inicjalizację parametrów oraz propagację w przód i wsteczną. Tym razem nie będzie trzeba tego robić, jednakże zdefiniujesz architekturę sieci przy użyciu modułu `torch.nn`.
#
# ***Zaimplementuj*** klasę Perceptron - klasę dziedziczącą po `nn.Module` z jedną warstwą transformacji liniowej (Perceptrona, [`torch.nn.Linear`](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html)). Na razie ***pomiń*** transformację nieliniową (np. sigmoid).

# %%
class Perceptron(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Linear(4, 3)
    
    def forward(self, x: torch.Tensor):
        return self.net(x)

# %% [markdown]
# Wspominmy tylko, że można nadal używać `torch.nn` i nie wykorzystywać gotowych warstw sieci tylko samemu implementować operacje na tensorach:
#
# ```
# class Perceptron(nn.Module):
#     def __init__(self, in_dim: int, out_dim: int):
#         super().__init__()
#         self.weights = nn.Parameter(
#           torch.randn(in_dim, out_dim) / math.sqrt(in_dim)
#         )
#         self.bias = nn.Parameter(torch.zeros(out_dim))
#
#     def forward(self, xb: torch.Tensor):
#         return xb @ self.weights + self.bias
# ```
# ***Przetestuj*** poprawność swojej implementacji.

# %%
model = Perceptron().cuda()
y_pred_0 = model(X_train[0])
print(y_pred_0)

assert isinstance(y_pred_0, torch.cuda.FloatTensor)
assert len(y_pred_0) == 3
# Out:
# tensor([-4.3154, -3.7125,  0.2079], device='cuda:0', grad_fn=<ViewBackward0>)

# %% [markdown]
# Wykorzystanie `nn.Linear` nie tylko odciążyło nas z implementacji operacji na tensorasch, ale także z inicjalizacji paprametrów modelu - inicjalizacja parametrów jest domyślnie implementowana przez daną wartstwę. Jeżeli uruchomisz powyższy kod wielokrotnie to zauważysz, że za każdym razem otrzymujesz inny tensor wyjściowy. Wynika to z tego, że początkowe parametry modelu są domyślnie **losowane**. Oznacza to, że proces uczenia będzie **niedeterministryczny** - każde uruchomienie da inny wynik parametrów, które model się nauczy.
#
# Pozostało jeszcze dodanie nieliniowej transformacji do sieci, ale nie będziemy tego robić. Dodatkowo zamiast tworzyć osobny klasifikator na klasę, zastosujemy jeden klasyfikator. W tym celu zmieniemy funkcję kosztu. Do klasyfikacji wieloklasowej wykorzystamy funkcję **straty krzyżowej entropii**.
#
# $\text{loss} = -\frac{1}{N}\sum_{i}^{N}\log(\text{softmax}(x_{i}){y_{i}}) $, gdzie $N$ oznacza liczbę przypadków, $x_{i}$ wyjście z ostatniej warstwy $i$-tej instancji, $y_{i}$ klasę $i$-tej instancji.
#
# **Softmax** jest przekstałceniem nielinowym powszechnie używanym jako ostatnia warstwa sieci neuronowej służącej do klasyfikacji. Jej mocną stroną jest to, że suma wszystkich elementów tensora będących na jej wyjściu wynosi $1$. Dzięki temu możemy wyjście sieci interpretować jako przypisanie pseudoprawdopodbieństwa dla klasyfikacji dla danej próbki.
#
# Dla danego wektora $\mathbf x = (x_1, x_2, \ldots, x_i, \ldots, x_C)$ funkcja Softmax jest zdefiniowana jako:
# $\text{Softmax}(x_{i}) = \frac{\exp(x_{i})}{\sum_{j}^{C} \exp(x_{j})}$, gdzie $C$ oznacza liczbę klas.
#
# W tym zadaniu nie będziemy implementować tych funkcji samemu tylko wykorzystamy gotową implementację w bibliotece torch. Implementację znajdziemy w [`torch.nn.CrossEntropyLoss`](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html). Przyjmuje ona "surowe" wartości, dlatego że oblicza również funkcję **LogSoftmax**. Alternatywnie możemy nałożyć funkcję aktywacji LogSoftmax z modułu [`torch.nn.LogSoftmax`](https://pytorch.org/docs/stable/generated/torch.nn.LogSoftmax.html) i obliczyć negatywny logarytm funkcji wiarygodności (ang. *negative log likelihood*) [`torch.nn.NLLLoss`](https://pytorch.org/docs/stable/generated/torch.nn.NLLLoss.html#torch.nn.NLLLoss). `torch.nn.NLLLoss` nie wykonuje operacji logarytmowania tylko oczekuje zlogarytmowanego wejścia.
#
# **LogSoftmax** wykorzystany jest tutaj nieprzypadkowo. Funkcja softmax w oryginalnej postaci nie jest odparna na wystąpienie niestabilności numerycznych. W przypadku liczenia entropii krzyżowej możemy wykorzystać skalę logarytmiczną do przeprowadzenia operacji. Dzięki przenesieniu obliczania logarytmu do funkcji Softmax możemy zastąpić dzielenie na różnicę logarytmów. czyli zamiast powyższej definicji funkcja LogSoftmax przyjmuję następującą postać:
#
# $\text{LogSoftmax}(x_{i}) = x_{i} - log \bigg({\sum_{j}^{C} \exp(x_{j})}\bigg)$
#
# Dodatkowo stosowany jest także trik polegający na zastąpieniu operacji $log \bigg({\sum_{j}^{C} \exp(x_{j})}\bigg)$ operacją **LogSumExp**, zdefiniowaną jako
#
# $\text{LogSumExp}(\mathbf x) = \max(\mathbf x) + log \bigg({\sum_{j}^{C} \exp(x_{j} - \max(\mathbf x))}\bigg)$.
#
# Pozwala to pozbyć się dużych wartości $x_{j}$ podczas obliczania $\exp$.

# %% [markdown]
# ## Algorytmy online i offline (`DataLoader`)
#
# Na poprzednich zajęciach zaimplementowałaś(eś) **algorytm offline** (alternatywnie batchowy lub deterministyczny, ang. *offline*, *batch*, *deterministic*) tzn. taki, który przetwarza od razu wszystkie dane. Jednakże implementując sieci neuronowe tworzymy często algorytmy **online** (alternatywnie stochastyczne, ang. *online*, *stochastic*), które przetwarzają dane w "kawałkach" lub wręcz mogą dostawać je "na bieżąco" bez konieczności posiadania wszystkcih danych przed uruchomieniem algorytmu. Są różne powody, dla których tak się robi, ale najczęstrzy jest taki, że przy głębszych architektrurach i bardziej złożonych obiektach (np. obrazach) byłoby fizycznie nie możliwe pomieścić te wszystkie dane w pamięci RAM lub VRAM (RAM na GPU) wraz z parametrami modelu.
#
# Liczbę próbek w algorytmach stochastycznych w sieciach neuronowych określa się jako **minibatch size** lub po prostu **batch size**. Przy czym określenie *batch size* nie odnosi się tutaj do algorytmów batchowych (operujących na całym zbiorze danych), tylko do algorytmów online/minibatch. Po prostu *batch size* jest określeniem krótszym (ale mniej poprawnym) niż *minibatch size*, stąd też powszechnie używa się tego pierwszego. Z tego też powodu czasami niektórzy używają określenia *batch* na *minibatch* - warto mieć to na uwadze przy komunikowaniu się z innymi osobami.
#
# Do zaimplementowania minibatchy wykorzystamy [`torch.utils.data.DataLoader`](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader). ***Zaimplementuj*** funkcję `to_dataloader`, która `X_train` i `y_train` oraz `X_test` i `y_test` umieści w dwóch osobnych instancjach klasy `DataLoader` z wielkością minibatacha równą `batch_size`

# %%
def to_dataloader(
    X_train: torch.Tensor, 
    y_train: torch.Tensor, 
    X_test: torch.Tensor, 
    y_test: torch.Tensor, 
    batch_size: int = 32,
    val_set: bool = False
) -> Tuple[DataLoader, DataLoader]:
    train_ds = TensorDataset(X_train, y_train)
    train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True)

    if val_set:
        test_ds = TensorDataset(X_test, y_test)
        n = len(test_ds)
        len_val = n // 2
        len_test = n - len_val

        val_subset, test_subset = torch.utils.data.random_split(
            test_ds,
            [len_val, len_test],
            generator=torch.Generator().manual_seed(1),
        )
        val_dl = DataLoader(val_subset, batch_size=batch_size)
        test_dl = DataLoader(test_subset, batch_size=batch_size)
    else:
        test_ds = TensorDataset(X_test, y_test)
        test_dl = DataLoader(test_ds, batch_size=batch_size)
        val_dl = None

    return train_dl, test_dl, val_dl

# %% [markdown]
# ***Przetestuj*** implementację

# %%
train_loader, test_loader, _ = to_dataloader(
    X_train=X_train,  y_train=y_train, 
    X_test=X_test, y_test=y_test, 
    batch_size=32
)

for sample in test_loader:
    print(sample)
# Out:
# [tensor([[5.1000, 3.8000, 1.9000, 0.4000],
#         [7.4000, 2.8000, 6.1000, 1.9000],
#         [4.6000, 3.2000, 1.4000, 0.2000],
#         [6.4000, 2.9000, 4.3000, 1.3000],
#         [7.3000, 2.9000, 6.3000, 1.8000],
#         [7.0000, 3.2000, 4.7000, 1.4000],
#         [5.1000, 2.5000, 3.0000, 1.1000],
#         [7.2000, 3.2000, 6.0000, 1.8000],
#         [6.7000, 2.5000, 5.8000, 1.8000],
#         [5.0000, 3.4000, 1.5000, 0.2000],
#         [6.1000, 3.0000, 4.9000, 1.8000],
#         [5.1000, 3.5000, 1.4000, 0.2000],
#         [6.9000, 3.2000, 5.7000, 2.3000],
#         [6.2000, 3.4000, 5.4000, 2.3000],
#         [6.0000, 3.4000, 4.5000, 1.6000],
#         [6.1000, 3.0000, 4.6000, 1.4000],
#         [6.8000, 3.0000, 5.5000, 2.1000],
#         [6.8000, 2.8000, 4.8000, 1.4000],
#         [5.7000, 2.5000, 5.0000, 2.0000],
#         [6.2000, 2.2000, 4.5000, 1.5000],
#         [5.7000, 4.4000, 1.5000, 0.4000],
#         [5.0000, 3.5000, 1.6000, 0.6000],
#         [6.7000, 3.3000, 5.7000, 2.5000],
#         [4.4000, 2.9000, 1.4000, 0.2000],
#         [5.6000, 2.7000, 4.2000, 1.3000],
#         [6.6000, 3.0000, 4.4000, 1.4000],
#         [5.9000, 3.0000, 5.1000, 1.8000],
#         [5.4000, 3.9000, 1.7000, 0.4000],
#         [6.7000, 3.1000, 5.6000, 2.4000],
#         [4.9000, 3.0000, 1.4000, 0.2000],
#         [4.6000, 3.4000, 1.4000, 0.3000],
#         [5.7000, 2.8000, 4.1000, 1.3000]], device='cuda:0'), tensor([0, 2, 0, 1, 2, 1, 1, 2, 2, 0, 2, 0, 2, 2, 1, 1, 2, 1, 2, 1, 0, 0, 2, 0,
#         1, 1, 2, 0, 2, 0, 0, 1], device='cuda:0')]
# [tensor([[6.7000, 3.1000, 4.4000, 1.4000],
#         [6.5000, 3.0000, 5.5000, 1.8000],
#         [6.4000, 2.7000, 5.3000, 1.9000],
#         [4.8000, 3.4000, 1.6000, 0.2000],
#         [5.2000, 3.4000, 1.4000, 0.2000],
#         [5.4000, 3.4000, 1.7000, 0.2000],
#         [4.8000, 3.0000, 1.4000, 0.1000],
#         [6.5000, 3.0000, 5.2000, 2.0000],
#         [6.5000, 2.8000, 4.6000, 1.5000],
#         [7.1000, 3.0000, 5.9000, 2.1000],
#         [4.9000, 3.1000, 1.5000, 0.2000],
#         [5.4000, 3.9000, 1.3000, 0.4000],
#         [6.5000, 3.0000, 5.8000, 2.2000],
#         [4.9000, 2.5000, 4.5000, 1.7000],
#         [6.1000, 2.8000, 4.7000, 1.2000],
#         [4.9000, 3.1000, 1.5000, 0.1000],
#         [5.0000, 3.0000, 1.6000, 0.2000],
#         [4.9000, 2.4000, 3.3000, 1.0000],
#         [6.9000, 3.1000, 5.1000, 2.3000],
#         [5.5000, 2.3000, 4.0000, 1.3000],
#         [5.6000, 3.0000, 4.5000, 1.5000],
#         [6.3000, 3.3000, 4.7000, 1.6000],
#         [5.6000, 2.8000, 4.9000, 2.0000],
#         [5.4000, 3.0000, 4.5000, 1.5000],
#         [5.7000, 3.8000, 1.7000, 0.3000],
#         [4.9000, 3.6000, 1.4000, 0.1000],
#         [6.0000, 2.2000, 4.0000, 1.0000],
#         [6.1000, 2.8000, 4.0000, 1.3000]], device='cuda:0'), tensor([1, 2, 2, 0, 0, 0, 0, 2, 1, 2, 0, 0, 2, 2, 1, 0, 0, 1, 2, 1, 1, 1, 2, 1,
#         0, 0, 1, 1], device='cuda:0')]

# %% [markdown]
# ## Ewaluacja modelu - metryki
#
# ***Zaimplementuj*** funkcję `validate`, które dla danego modelu, funkcji straty i loadera zwróci średnią wartość funkcji straty oraz dokładność (ang. *accuracy*) dla danych z `dataloader`.

# %%
def count_correct(
    y_pred: torch.Tensor, y_true: torch.Tensor
) -> torch.Tensor:
    preds = torch.argmax(y_pred, dim=1)
    return (preds == y_true).float().sum()

def validate(
    model: nn.Module, 
    loss_fn: torch.nn.CrossEntropyLoss, 
    dataloader: DataLoader
) -> Tuple[torch.Tensor, torch.Tensor]:
    loss = 0
    correct = 0
    all = 0
    for X_batch, y_batch in dataloader:
        y_pred = model(X_batch)
        all += len(y_pred)
        loss += loss_fn(y_pred, y_batch).sum()
        correct += count_correct(y_pred, y_batch)
    return loss / all, correct / all

# %% [markdown]
# ***Przetestuj*** swoją implementację

# %%
loss_fn = torch.nn.CrossEntropyLoss()
val_train, acc_train = validate(model, loss_fn, test_loader)
print(val_train, acc_train)
# Out:
# tensor(0.0641, device='cuda:0', grad_fn=<DivBackward0>) tensor(0.3333, device='cuda:0')

# %% [markdown]
# ## Uczenie
#
# Przed uzupełnieniem poniżej implementacji została nam jeszcze jedna istotna kwestia do poruszenia. Otóż dot tej pory aktualizację parametrów dokonywaliśmy wg prostej formuły - mnożyliśmy gradienty przez współczynnik uczenia (ang. *learning rate*) i odejmowalismy od parametrów. Jednakże do uczenia sieci neuronowych sotsujemy często optymalizatory (ang. *optimiser*), które mogą implementować różne podejścia do uakualiniania parameterów modelu. Wykorzystamy tutaj algorytm **Adam** (ang. *adaptive moment estimation*), który dostosowuje współczynnik uczenia do poszczególnych parametrów i jest często optimizatorem pierwszego wyboru.
#
# ***Uzupełnij i przetestuj*** poniższą implementację uczenia modelu. Porównaj jej skuteczność z tą, którą zaimplementowałeś(aś) na laboratorium 2.

# %%
def fit(
    model: nn.Module, optimiser: optim.Optimizer, 
    loss_fn: torch.nn.CrossEntropyLoss, train_dl: DataLoader, 
    test_dl: DataLoader, epochs: int, 
    print_metrics: str = True, val_dl: DataLoader = None
):
    train_losses, train_accs, val_losses, val_accs, test_losses, test_accs = [], [], [], [], [], []
    for epoch in range(epochs):
        model.train() # Przełączenie na tryb uczenia modelu - istotne dla takich warstw jak Dropuot czy BatchNorm
        for X_batch, y_batch in train_dl:
            y_pred = model(X_batch) # Uzyskanie pseudoprawdopodobieństw dla próbek z minibatcha
            loss = loss_fn(y_pred, y_batch) # Policzenie funkcji straty

            loss.backward() # Wsteczna propagacja z wyniku funkcji straty - policzenie gradientów i zapisanie ich w tensorach (parametrach)
            optimiser.step() # Aktualizacja parametrów modelu przez optymalizator na podstawie gradientów zapisanych w tensorach (parametrach) oraz lr
            optimiser.zero_grad() # Wyzerowanie gradientów w modelu, alternatywnie można wywołać model.zero_grad()
        
        if print_metrics: 
            model.eval() # Przełączenie na tryb ewaluacji modelu - istotne dla takich warstw jak Dropuot czy BatchNorm
            with torch.no_grad():  # Wstrzymujemy przeliczanie i śledzenie gradientów dla tensorów - w procesie ewaluacji modelu nie chcemy zmian w gradientach
                train_loss, train_acc = validate(model, loss_fn, train_dl)
                test_loss, test_acc = validate(model, loss_fn, test_dl)
                if val_dl is not None:
                    val_loss, val_acc = validate(model, loss_fn, val_dl)
                    val_losses.append(val_loss)
                    val_accs.append(val_acc)
                test_losses.append(test_loss)
                test_accs.append(test_acc)
                train_losses.append(train_loss)
                train_accs.append(train_acc)
                
                print(
                    f"Epoch {epoch}: "
                    f"train loss = {train_loss:.3f} (acc: {train_acc:.3f}), "
                    f"test loss = {test_loss:.3f} (acc: {test_acc:.3f}), "
                )       
                if val_dl is not None:
                    print(f"val loss = {val_loss:.3f} (acc: {val_acc:.3f})")
                
      
    model.eval() # Przełączenie na tryb ewaluacji modelu - istotne dla takich warstw jak Dropuot czy BatchNorm
    return train_losses, train_accs, test_losses, test_accs, val_losses, val_accs

train_dl, test_dl,_ = to_dataloader(
    X_train=X_train, 
    y_train=y_train, 
    X_test=X_test, 
    y_test=y_test, 
    batch_size=32
)
perceptron = Perceptron().cuda()
optimiser = optim.Adam(perceptron.parameters(), lr=0.005)
loss_fn = torch.nn.CrossEntropyLoss()
train_losses, train_accs, test_losses, test_accs, _, _ = fit(
    model=perceptron, optimiser=optimiser, loss_fn=loss_fn, 
    train_dl=train_dl, test_dl=test_dl, epochs=500
)
# Out:
# Epoch 0: train loss = 0.048 (acc: 0.333), test loss = 0.048 (acc: 0.333),
# Epoch 1: train loss = 0.045 (acc: 0.378), test loss = 0.045 (acc: 0.333),
# Epoch 2: train loss = 0.043 (acc: 0.256), test loss = 0.043 (acc: 0.267),
# Epoch 3: train loss = 0.041 (acc: 0.333), test loss = 0.042 (acc: 0.317),
# Epoch 4: train loss = 0.041 (acc: 0.333), test loss = 0.041 (acc: 0.333),
# Epoch 5: train loss = 0.040 (acc: 0.333), test loss = 0.040 (acc: 0.333),
# Epoch 6: train loss = 0.039 (acc: 0.333), test loss = 0.039 (acc: 0.333),
# Epoch 7: train loss = 0.038 (acc: 0.333), test loss = 0.038 (acc: 0.333),
# Epoch 8: train loss = 0.037 (acc: 0.333), test loss = 0.037 (acc: 0.333),
# Epoch 9: train loss = 0.036 (acc: 0.333), test loss = 0.036 (acc: 0.333),
# Epoch 10: train loss = 0.035 (acc: 0.333), test loss = 0.035 (acc: 0.333),
# Epoch 11: train loss = 0.034 (acc: 0.311), test loss = 0.035 (acc: 0.350),
# Epoch 12: train loss = 0.034 (acc: 0.333), test loss = 0.034 (acc: 0.317),
# Epoch 13: train loss = 0.033 (acc: 0.333), test loss = 0.033 (acc: 0.317),
# Epoch 14: train loss = 0.032 (acc: 0.333), test loss = 0.033 (acc: 0.333),
# Epoch 15: train loss = 0.032 (acc: 0.333), test loss = 0.032 (acc: 0.383),
# Epoch 16: train loss = 0.031 (acc: 0.456), test loss = 0.031 (acc: 0.517),
# Epoch 17: train loss = 0.030 (acc: 0.589), test loss = 0.031 (acc: 0.583),
# Epoch 18: train loss = 0.030 (acc: 0.667), test loss = 0.030 (acc: 0.667),
# Epoch 19: train loss = 0.029 (acc: 0.678), test loss = 0.030 (acc: 0.667),
# Epoch 20: train loss = 0.029 (acc: 0.667), test loss = 0.029 (acc: 0.683),
# Epoch 21: train loss = 0.028 (acc: 0.678), test loss = 0.028 (acc: 0.683),
# Epoch 22: train loss = 0.028 (acc: 0.678), test loss = 0.028 (acc: 0.683),
# Epoch 23: train loss = 0.027 (acc: 0.678), test loss = 0.027 (acc: 0.683),
# Epoch 24: train loss = 0.027 (acc: 0.678), test loss = 0.027 (acc: 0.683),
# Epoch 25: train loss = 0.026 (acc: 0.678), test loss = 0.027 (acc: 0.683),
# Epoch 26: train loss = 0.026 (acc: 0.678), test loss = 0.026 (acc: 0.700),
# Epoch 27: train loss = 0.025 (acc: 0.678), test loss = 0.026 (acc: 0.700),
# Epoch 28: train loss = 0.025 (acc: 0.678), test loss = 0.025 (acc: 0.700),
# Epoch 29: train loss = 0.025 (acc: 0.678), test loss = 0.025 (acc: 0.700),
# Epoch 30: train loss = 0.024 (acc: 0.689), test loss = 0.025 (acc: 0.683),
# Epoch 31: train loss = 0.024 (acc: 0.689), test loss = 0.024 (acc: 0.700),
# Epoch 32: train loss = 0.024 (acc: 0.689), test loss = 0.024 (acc: 0.700),
# Epoch 33: train loss = 0.023 (acc: 0.678), test loss = 0.024 (acc: 0.700),
# Epoch 34: train loss = 0.023 (acc: 0.678), test loss = 0.024 (acc: 0.700),
# Epoch 35: train loss = 0.023 (acc: 0.689), test loss = 0.023 (acc: 0.717),
# Epoch 36: train loss = 0.023 (acc: 0.689), test loss = 0.023 (acc: 0.717),
# Epoch 37: train loss = 0.022 (acc: 0.711), test loss = 0.023 (acc: 0.717),
# Epoch 38: train loss = 0.022 (acc: 0.733), test loss = 0.022 (acc: 0.717),
# Epoch 39: train loss = 0.022 (acc: 0.744), test loss = 0.022 (acc: 0.717),
# Epoch 40: train loss = 0.022 (acc: 0.744), test loss = 0.022 (acc: 0.717),
# Epoch 41: train loss = 0.022 (acc: 0.733), test loss = 0.022 (acc: 0.717),
# Epoch 42: train loss = 0.021 (acc: 0.711), test loss = 0.022 (acc: 0.717),
# Epoch 43: train loss = 0.021 (acc: 0.700), test loss = 0.021 (acc: 0.717),
# Epoch 44: train loss = 0.021 (acc: 0.689), test loss = 0.021 (acc: 0.717),
# Epoch 45: train loss = 0.021 (acc: 0.733), test loss = 0.021 (acc: 0.717),
# Epoch 46: train loss = 0.020 (acc: 0.733), test loss = 0.021 (acc: 0.717),
# Epoch 47: train loss = 0.020 (acc: 0.733), test loss = 0.021 (acc: 0.717),
# Epoch 48: train loss = 0.020 (acc: 0.733), test loss = 0.020 (acc: 0.717),
# Epoch 49: train loss = 0.020 (acc: 0.767), test loss = 0.020 (acc: 0.750),
# Epoch 50: train loss = 0.020 (acc: 0.756), test loss = 0.020 (acc: 0.733),
# Epoch 51: train loss = 0.020 (acc: 0.778), test loss = 0.020 (acc: 0.750),
# Epoch 52: train loss = 0.020 (acc: 0.789), test loss = 0.020 (acc: 0.767),
# Epoch 53: train loss = 0.019 (acc: 0.778), test loss = 0.020 (acc: 0.767),
# Epoch 54: train loss = 0.019 (acc: 0.778), test loss = 0.019 (acc: 0.767),
# Epoch 55: train loss = 0.019 (acc: 0.767), test loss = 0.019 (acc: 0.733),
# Epoch 56: train loss = 0.019 (acc: 0.756), test loss = 0.019 (acc: 0.733),
# Epoch 57: train loss = 0.019 (acc: 0.744), test loss = 0.019 (acc: 0.717),
# Epoch 58: train loss = 0.019 (acc: 0.778), test loss = 0.019 (acc: 0.783),
# Epoch 59: train loss = 0.019 (acc: 0.778), test loss = 0.019 (acc: 0.783),
# Epoch 60: train loss = 0.018 (acc: 0.789), test loss = 0.019 (acc: 0.800),
# Epoch 61: train loss = 0.018 (acc: 0.822), test loss = 0.019 (acc: 0.850),
# Epoch 62: train loss = 0.018 (acc: 0.811), test loss = 0.018 (acc: 0.850),
# Epoch 63: train loss = 0.018 (acc: 0.778), test loss = 0.018 (acc: 0.783),
# Epoch 64: train loss = 0.018 (acc: 0.778), test loss = 0.018 (acc: 0.750),
# Epoch 65: train loss = 0.018 (acc: 0.778), test loss = 0.018 (acc: 0.750),
# Epoch 66: train loss = 0.018 (acc: 0.778), test loss = 0.018 (acc: 0.750),
# Epoch 67: train loss = 0.018 (acc: 0.789), test loss = 0.018 (acc: 0.783),
# Epoch 68: train loss = 0.018 (acc: 0.800), test loss = 0.018 (acc: 0.817),
# Epoch 69: train loss = 0.017 (acc: 0.867), test loss = 0.018 (acc: 0.883),
# Epoch 70: train loss = 0.017 (acc: 0.900), test loss = 0.018 (acc: 0.900),
# Epoch 71: train loss = 0.017 (acc: 0.900), test loss = 0.017 (acc: 0.900),
# Epoch 72: train loss = 0.017 (acc: 0.900), test loss = 0.017 (acc: 0.900),
# Epoch 73: train loss = 0.017 (acc: 0.844), test loss = 0.017 (acc: 0.817),
# Epoch 74: train loss = 0.017 (acc: 0.844), test loss = 0.017 (acc: 0.817),
# Epoch 75: train loss = 0.017 (acc: 0.844), test loss = 0.017 (acc: 0.817),
# Epoch 76: train loss = 0.017 (acc: 0.844), test loss = 0.017 (acc: 0.817),
# Epoch 77: train loss = 0.016 (acc: 0.844), test loss = 0.017 (acc: 0.833),
# Epoch 78: train loss = 0.017 (acc: 0.867), test loss = 0.017 (acc: 0.883),
# Epoch 79: train loss = 0.016 (acc: 0.889), test loss = 0.017 (acc: 0.900),
# Epoch 80: train loss = 0.017 (acc: 0.878), test loss = 0.017 (acc: 0.900),
# Epoch 81: train loss = 0.016 (acc: 0.878), test loss = 0.017 (acc: 0.900),
# Epoch 82: train loss = 0.016 (acc: 0.878), test loss = 0.016 (acc: 0.883),
# Epoch 83: train loss = 0.016 (acc: 0.867), test loss = 0.016 (acc: 0.883),
# Epoch 84: train loss = 0.016 (acc: 0.867), test loss = 0.016 (acc: 0.883),
# Epoch 85: train loss = 0.016 (acc: 0.900), test loss = 0.016 (acc: 0.900),
# Epoch 86: train loss = 0.016 (acc: 0.900), test loss = 0.016 (acc: 0.900),
# Epoch 87: train loss = 0.016 (acc: 0.878), test loss = 0.016 (acc: 0.900),
# Epoch 88: train loss = 0.016 (acc: 0.878), test loss = 0.016 (acc: 0.900),
# Epoch 89: train loss = 0.016 (acc: 0.878), test loss = 0.016 (acc: 0.900),
# Epoch 90: train loss = 0.016 (acc: 0.900), test loss = 0.016 (acc: 0.900),
# Epoch 91: train loss = 0.016 (acc: 0.900), test loss = 0.016 (acc: 0.917),
# Epoch 92: train loss = 0.016 (acc: 0.900), test loss = 0.016 (acc: 0.900),
# Epoch 93: train loss = 0.015 (acc: 0.911), test loss = 0.016 (acc: 0.917),
# Epoch 94: train loss = 0.015 (acc: 0.922), test loss = 0.016 (acc: 0.933),
# Epoch 95: train loss = 0.015 (acc: 0.956), test loss = 0.016 (acc: 0.967),
# Epoch 96: train loss = 0.015 (acc: 0.911), test loss = 0.015 (acc: 0.917),
# Epoch 97: train loss = 0.015 (acc: 0.900), test loss = 0.015 (acc: 0.917),
# Epoch 98: train loss = 0.015 (acc: 0.900), test loss = 0.015 (acc: 0.917),
# Epoch 99: train loss = 0.015 (acc: 0.889), test loss = 0.015 (acc: 0.900),
# Epoch 100: train loss = 0.015 (acc: 0.889), test loss = 0.015 (acc: 0.917),
# Epoch 101: train loss = 0.015 (acc: 0.900), test loss = 0.015 (acc: 0.917),
# Epoch 102: train loss = 0.015 (acc: 0.911), test loss = 0.015 (acc: 0.933),
# Epoch 103: train loss = 0.015 (acc: 0.911), test loss = 0.015 (acc: 0.917),
# Epoch 104: train loss = 0.015 (acc: 0.944), test loss = 0.015 (acc: 0.967),
# Epoch 105: train loss = 0.015 (acc: 0.956), test loss = 0.015 (acc: 0.983),
# Epoch 106: train loss = 0.015 (acc: 0.956), test loss = 0.015 (acc: 0.983),
# Epoch 107: train loss = 0.015 (acc: 0.956), test loss = 0.015 (acc: 0.983),
# Epoch 108: train loss = 0.014 (acc: 0.944), test loss = 0.015 (acc: 0.967),
# Epoch 109: train loss = 0.015 (acc: 0.933), test loss = 0.015 (acc: 0.967),
# Epoch 110: train loss = 0.015 (acc: 0.911), test loss = 0.015 (acc: 0.933),
# Epoch 111: train loss = 0.014 (acc: 0.889), test loss = 0.015 (acc: 0.883),
# Epoch 112: train loss = 0.014 (acc: 0.889), test loss = 0.014 (acc: 0.883),
# Epoch 113: train loss = 0.014 (acc: 0.889), test loss = 0.014 (acc: 0.900),
# Epoch 114: train loss = 0.014 (acc: 0.933), test loss = 0.014 (acc: 0.967),
# Epoch 115: train loss = 0.014 (acc: 0.956), test loss = 0.014 (acc: 0.983),
# Epoch 116: train loss = 0.014 (acc: 0.956), test loss = 0.014 (acc: 0.983),
# Epoch 117: train loss = 0.014 (acc: 0.944), test loss = 0.014 (acc: 0.983),
# Epoch 118: train loss = 0.014 (acc: 0.944), test loss = 0.014 (acc: 0.967),
# Epoch 119: train loss = 0.014 (acc: 0.922), test loss = 0.014 (acc: 0.950),
# Epoch 120: train loss = 0.014 (acc: 0.933), test loss = 0.014 (acc: 0.967),
# Epoch 121: train loss = 0.014 (acc: 0.944), test loss = 0.014 (acc: 0.983),
# Epoch 122: train loss = 0.014 (acc: 0.944), test loss = 0.014 (acc: 0.983),
# Epoch 123: train loss = 0.014 (acc: 0.944), test loss = 0.014 (acc: 0.983),
# Epoch 124: train loss = 0.014 (acc: 0.944), test loss = 0.014 (acc: 0.983),
# Epoch 125: train loss = 0.014 (acc: 0.944), test loss = 0.014 (acc: 0.983),
# Epoch 126: train loss = 0.014 (acc: 0.944), test loss = 0.014 (acc: 0.983),
# Epoch 127: train loss = 0.013 (acc: 0.944), test loss = 0.014 (acc: 0.983),
# Epoch 128: train loss = 0.014 (acc: 0.944), test loss = 0.014 (acc: 0.983),
# Epoch 129: train loss = 0.013 (acc: 0.944), test loss = 0.014 (acc: 0.983),
# Epoch 130: train loss = 0.013 (acc: 0.944), test loss = 0.014 (acc: 0.983),
# Epoch 131: train loss = 0.013 (acc: 0.944), test loss = 0.013 (acc: 0.983),
# Epoch 132: train loss = 0.013 (acc: 0.944), test loss = 0.013 (acc: 0.983),
# Epoch 133: train loss = 0.013 (acc: 0.944), test loss = 0.013 (acc: 0.983),
# Epoch 134: train loss = 0.013 (acc: 0.956), test loss = 0.013 (acc: 0.983),
# Epoch 135: train loss = 0.013 (acc: 0.956), test loss = 0.013 (acc: 0.983),
# Epoch 136: train loss = 0.013 (acc: 0.956), test loss = 0.013 (acc: 0.983),
# Epoch 137: train loss = 0.013 (acc: 0.956), test loss = 0.013 (acc: 0.983),
# Epoch 138: train loss = 0.013 (acc: 0.956), test loss = 0.013 (acc: 0.983),
# Epoch 139: train loss = 0.013 (acc: 0.956), test loss = 0.013 (acc: 0.983),
# Epoch 140: train loss = 0.013 (acc: 0.956), test loss = 0.013 (acc: 0.983),
# Epoch 141: train loss = 0.013 (acc: 0.956), test loss = 0.013 (acc: 0.983),
# Epoch 142: train loss = 0.013 (acc: 0.956), test loss = 0.013 (acc: 0.983),
# Epoch 143: train loss = 0.013 (acc: 0.944), test loss = 0.013 (acc: 0.983),
# Epoch 144: train loss = 0.013 (acc: 0.944), test loss = 0.013 (acc: 0.983),
# Epoch 145: train loss = 0.013 (acc: 0.944), test loss = 0.013 (acc: 0.983),
# Epoch 146: train loss = 0.013 (acc: 0.956), test loss = 0.013 (acc: 0.983),
# Epoch 147: train loss = 0.013 (acc: 0.956), test loss = 0.013 (acc: 0.983),
# Epoch 148: train loss = 0.013 (acc: 0.956), test loss = 0.013 (acc: 0.983),
# Epoch 149: train loss = 0.013 (acc: 0.956), test loss = 0.013 (acc: 0.983),
# Epoch 150: train loss = 0.013 (acc: 0.956), test loss = 0.013 (acc: 0.983),
# Epoch 151: train loss = 0.012 (acc: 0.956), test loss = 0.013 (acc: 0.983),
# Epoch 152: train loss = 0.013 (acc: 0.956), test loss = 0.013 (acc: 0.983),
# Epoch 153: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 154: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 155: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 156: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 157: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 158: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 159: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 160: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 161: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 162: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 163: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 164: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 165: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 166: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 167: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 168: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 169: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 170: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 171: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 172: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 173: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 174: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 175: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 176: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 177: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 178: train loss = 0.012 (acc: 0.956), test loss = 0.012 (acc: 0.983),
# Epoch 179: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 180: train loss = 0.012 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 181: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 182: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 183: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 184: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 185: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 186: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 187: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 188: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 189: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 190: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 191: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 192: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 193: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 194: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 195: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 196: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 197: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 198: train loss = 0.011 (acc: 0.967), test loss = 0.011 (acc: 0.983),
# Epoch 199: train loss = 0.011 (acc: 0.967), test loss = 0.011 (acc: 0.983),
# Epoch 200: train loss = 0.011 (acc: 0.967), test loss = 0.011 (acc: 0.983),
# Epoch 201: train loss = 0.011 (acc: 0.967), test loss = 0.011 (acc: 0.983),
# Epoch 202: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 203: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 204: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 205: train loss = 0.011 (acc: 0.956), test loss = 0.011 (acc: 0.983),
# Epoch 206: train loss = 0.011 (acc: 0.967), test loss = 0.011 (acc: 0.983),
# Epoch 207: train loss = 0.011 (acc: 0.967), test loss = 0.011 (acc: 0.983),
# Epoch 208: train loss = 0.011 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 209: train loss = 0.011 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 210: train loss = 0.011 (acc: 0.956), test loss = 0.010 (acc: 0.983),
# Epoch 211: train loss = 0.010 (acc: 0.956), test loss = 0.010 (acc: 0.983),
# Epoch 212: train loss = 0.010 (acc: 0.956), test loss = 0.010 (acc: 0.983),
# Epoch 213: train loss = 0.011 (acc: 0.956), test loss = 0.010 (acc: 0.983),
# Epoch 214: train loss = 0.010 (acc: 0.956), test loss = 0.010 (acc: 0.983),
# Epoch 215: train loss = 0.011 (acc: 0.956), test loss = 0.010 (acc: 0.983),
# Epoch 216: train loss = 0.011 (acc: 0.956), test loss = 0.010 (acc: 0.983),
# Epoch 217: train loss = 0.010 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 218: train loss = 0.010 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 219: train loss = 0.010 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 220: train loss = 0.010 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 221: train loss = 0.010 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 222: train loss = 0.010 (acc: 0.956), test loss = 0.010 (acc: 0.983),
# Epoch 223: train loss = 0.010 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 224: train loss = 0.010 (acc: 0.956), test loss = 0.010 (acc: 0.983),
# Epoch 225: train loss = 0.010 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 226: train loss = 0.010 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 227: train loss = 0.010 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 228: train loss = 0.010 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 229: train loss = 0.010 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 230: train loss = 0.010 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 231: train loss = 0.010 (acc: 0.956), test loss = 0.010 (acc: 0.983),
# Epoch 232: train loss = 0.010 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 233: train loss = 0.010 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 234: train loss = 0.010 (acc: 0.956), test loss = 0.010 (acc: 0.983),
# Epoch 235: train loss = 0.010 (acc: 0.956), test loss = 0.010 (acc: 0.983),
# Epoch 236: train loss = 0.010 (acc: 0.956), test loss = 0.010 (acc: 0.983),
# Epoch 237: train loss = 0.010 (acc: 0.956), test loss = 0.010 (acc: 0.983),
# Epoch 238: train loss = 0.010 (acc: 0.956), test loss = 0.010 (acc: 0.983),
# Epoch 239: train loss = 0.010 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 240: train loss = 0.010 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 241: train loss = 0.010 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 242: train loss = 0.010 (acc: 0.967), test loss = 0.010 (acc: 0.983),
# Epoch 243: train loss = 0.010 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 244: train loss = 0.010 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 245: train loss = 0.010 (acc: 0.956), test loss = 0.009 (acc: 0.983),
# Epoch 246: train loss = 0.010 (acc: 0.956), test loss = 0.009 (acc: 0.983),
# Epoch 247: train loss = 0.010 (acc: 0.956), test loss = 0.009 (acc: 0.983),
# Epoch 248: train loss = 0.009 (acc: 0.956), test loss = 0.009 (acc: 0.983),
# Epoch 249: train loss = 0.010 (acc: 0.956), test loss = 0.009 (acc: 0.983),
# Epoch 250: train loss = 0.010 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 251: train loss = 0.010 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 252: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 253: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 254: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 255: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 256: train loss = 0.010 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 257: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 258: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 259: train loss = 0.009 (acc: 0.956), test loss = 0.009 (acc: 0.983),
# Epoch 260: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 261: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 262: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 263: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 264: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 265: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 266: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 267: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 268: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 269: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 270: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 271: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 272: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 273: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 274: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 275: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 276: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 277: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 278: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 279: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 280: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 281: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 1.000),
# Epoch 282: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 1.000),
# Epoch 283: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 1.000),
# Epoch 284: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 1.000),
# Epoch 285: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 0.983),
# Epoch 286: train loss = 0.009 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 287: train loss = 0.009 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 288: train loss = 0.009 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 289: train loss = 0.009 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 290: train loss = 0.009 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 291: train loss = 0.009 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 292: train loss = 0.009 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 293: train loss = 0.009 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 294: train loss = 0.009 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 295: train loss = 0.009 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 296: train loss = 0.009 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 297: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 298: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 299: train loss = 0.009 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 300: train loss = 0.008 (acc: 0.956), test loss = 0.008 (acc: 1.000),
# Epoch 301: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 302: train loss = 0.009 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 303: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 304: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 305: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 306: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 307: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 308: train loss = 0.008 (acc: 0.956), test loss = 0.008 (acc: 1.000),
# Epoch 309: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 310: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 311: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 312: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 313: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 314: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 315: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 316: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 317: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 318: train loss = 0.008 (acc: 0.956), test loss = 0.008 (acc: 1.000),
# Epoch 319: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 320: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 321: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 322: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 323: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 324: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 325: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 326: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 327: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 328: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 329: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 330: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 331: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 332: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 333: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 334: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 335: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 0.983),
# Epoch 336: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 337: train loss = 0.008 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# Epoch 338: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 339: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 340: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 341: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 342: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 343: train loss = 0.008 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 344: train loss = 0.008 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 345: train loss = 0.008 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 346: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 347: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 348: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 349: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 350: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 351: train loss = 0.008 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 352: train loss = 0.008 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 353: train loss = 0.008 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 354: train loss = 0.008 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 355: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 356: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 357: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 358: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 359: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 360: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 361: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 362: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 363: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 364: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 365: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 366: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 367: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 368: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 369: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 370: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 371: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 372: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 373: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 374: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 375: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 376: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 377: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 378: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 379: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 380: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 381: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 382: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 383: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 384: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 385: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 386: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 387: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 388: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 389: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 390: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 391: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 392: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 393: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 394: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 395: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 396: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 397: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 398: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 399: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# Epoch 400: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 401: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 402: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 403: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 404: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# Epoch 405: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 406: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 407: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 408: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 409: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 410: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 411: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 412: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 413: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 414: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 415: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 416: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 417: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 418: train loss = 0.007 (acc: 0.967), test loss = 0.006 (acc: 1.000),
# Epoch 419: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 420: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 421: train loss = 0.007 (acc: 0.967), test loss = 0.006 (acc: 1.000),
# Epoch 422: train loss = 0.007 (acc: 0.967), test loss = 0.006 (acc: 1.000),
# Epoch 423: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 424: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 425: train loss = 0.007 (acc: 0.967), test loss = 0.006 (acc: 1.000),
# Epoch 426: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 427: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 428: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 429: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 430: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 431: train loss = 0.007 (acc: 0.967), test loss = 0.006 (acc: 1.000),
# Epoch 432: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 433: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 434: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 435: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 436: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 437: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 438: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 439: train loss = 0.007 (acc: 0.967), test loss = 0.006 (acc: 1.000),
# Epoch 440: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 441: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 442: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 443: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 444: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 445: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 446: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 447: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 448: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 449: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 450: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 451: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 452: train loss = 0.007 (acc: 0.967), test loss = 0.006 (acc: 1.000),
# Epoch 453: train loss = 0.006 (acc: 0.967), test loss = 0.006 (acc: 1.000),
# Epoch 454: train loss = 0.007 (acc: 0.967), test loss = 0.006 (acc: 1.000),
# Epoch 455: train loss = 0.006 (acc: 0.967), test loss = 0.006 (acc: 1.000),
# Epoch 456: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 457: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 458: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 459: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 460: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 461: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 462: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 463: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 464: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 465: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 466: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 467: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 468: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 469: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 470: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 471: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 472: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 473: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 474: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 475: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 476: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 477: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 478: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 479: train loss = 0.006 (acc: 0.967), test loss = 0.006 (acc: 1.000),
# Epoch 480: train loss = 0.006 (acc: 0.967), test loss = 0.006 (acc: 1.000),
# Epoch 481: train loss = 0.006 (acc: 0.967), test loss = 0.006 (acc: 1.000),
# Epoch 482: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 483: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 484: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 485: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 486: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 487: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 488: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 489: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 490: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 491: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# Epoch 492: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# Epoch 493: train loss = 0.006 (acc: 0.967), test loss = 0.005 (acc: 1.000),
# Epoch 494: train loss = 0.006 (acc: 0.967), test loss = 0.005 (acc: 1.000),
# Epoch 495: train loss = 0.006 (acc: 0.967), test loss = 0.005 (acc: 1.000),
# Epoch 496: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# Epoch 497: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# Epoch 498: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# Epoch 499: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),

# %%
import matplotlib.pyplot as plt


def plot_metrics(
    train_losses, train_accs, test_losses, test_accs, val_losses=None, val_accs=None
):
# Konwersja do zwyklych floatow (dziala niezaleznie od tego, czy sa to tensory czy floaty)
    train_losses_plot = [float(x.detach().cpu()) if torch.is_tensor(x) else float(x) for x in train_losses]
    test_losses_plot = [float(x.detach().cpu()) if torch.is_tensor(x) else float(x) for x in test_losses]
    train_accs_plot = [float(x.detach().cpu()) if torch.is_tensor(x) else float(x) for x in train_accs]
    test_accs_plot = [float(x.detach().cpu()) if torch.is_tensor(x) else float(x) for x in test_accs]
    if val_losses is not None and val_accs is not None:
        val_losses_plot = [float(x.detach().cpu()) if torch.is_tensor(x) else float(x) for x in val_losses]
        val_accs_plot = [float(x.detach().cpu()) if torch.is_tensor(x) else float(x) for x in val_accs]

    def plot_metric(metric_train, metric_test, metric_val=None, ylabel="", title=""):
        plt.figure(figsize=(10, 5))
        plt.plot(epochs, metric_train, label="train", linewidth=2)
        plt.plot(epochs, metric_test, label="test", linewidth=2)
        if metric_val is not None:
            plt.plot(epochs, metric_val, label="val", linewidth=2)
        plt.xlabel("Epoka")
        plt.ylabel(ylabel)
        plt.title(title)
        plt.legend()
        plt.tight_layout()
        plt.show()

    epochs = range(1, len(train_losses_plot) + 1)
    # Wykres 1: funkcja kosztu
    plot_metric(train_losses_plot, test_losses_plot, val_losses_plot if val_losses is not None else None, ylabel="Loss", title="Funkcja kosztu w zaleznosci od epoki")
    # Wykres 2: accuracy
    plot_metric(train_accs_plot, test_accs_plot, val_accs_plot if val_accs is not None else None, ylabel="Accuracy", title="Accuracy w zaleznosci od epoki")


plot_metrics(train_losses, train_accs, test_losses, test_accs)

# %% [markdown]
# ***Uzupełnij*** funkcję `fit`, aby ta mogła logować metryki (*loss*, *accuracy*) per epokę. Po zebraniu historii uczenia ***przedstaw*** następujące wykresy:
# - Wykres wartości funkcji kosztu w zależności od epoki uczenia dla zbioru uczącego i testowego
# - Wykres wartości metryki *accuracy* w zależności od epoki uczenia dla zbioru uczącego i testowego
#
# Metryki dla obu zbiorów przedstaw na jednym wykresie jako serie. ***Uzupełnij*** etykiety osi i tytuły wykresów.

# %% [markdown]
# ***Popraw*** model, tak aby otrzymać dokładność na zbiorze testowym wynoszącą co najmniej 90%. W tym celu dobierz odpowiedni współczynnik uczenia i liczbę epok.
# Do porównania badanych hiperparametrów użyj zbioru walidacyjnego. Podziel zbiór testowy na dwie równe części, jeden który będzie służyć do walidacji hiperparametrów, a drugi, który będzie służył do ewaluacji znalezionej najlepszej pary hiperparametrów. W tym celu możesz wykorzystać funkcję `torch.utils.data.random_split` z ustawionym parametrem `generator=torch.Generator().manual_seed(1)`. Przedstaw równiez wykresy o których mowa punkcie powyżej tym razem z uwzględniem trzech zbiorów (uczącego, walidacyjnego i testowego)

# %%
X, y = load_iris(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1, stratify=y)

X_train = torch.tensor(X_train).float().cuda()
X_test = torch.tensor(X_test).float().cuda()
y_train = torch.tensor(y_train).cuda()
y_test = torch.tensor(y_test).cuda()


train_dl, test_dl, val_dl = to_dataloader(
    X_train=X_train,  y_train=y_train, 
    X_test=X_test, y_test=y_test, 
    batch_size=32, val_set=True
)

LR_TEST = [0.1, 0.01, 0.005, 0.001]
EPOCHS_TEST = [100, 200, 500, 1000]

best_lr = None
best_epochs = None
best_acc = 0
best_metrics = None
same_accs = 0

for lr in LR_TEST:
    for epochs in EPOCHS_TEST:
        print(f"LR: {lr}, epochs: {epochs}")
        perceptron = Perceptron().cuda()
        optimiser = optim.Adam(perceptron.parameters(), lr=lr)
        loss_fn = torch.nn.CrossEntropyLoss()
        train_losses, train_accs, test_losses, test_accs, val_losses, val_accs = fit(
            model=perceptron, optimiser=optimiser, loss_fn=loss_fn, 
            train_dl=train_dl, test_dl=test_dl, val_dl=val_dl, epochs=epochs, print_metrics=True
        )

        if val_accs[-1] > best_acc:
            best_acc = val_accs[-1]
            best_lr = lr
            best_epochs = epochs
            best_metrics = (train_losses, train_accs, test_losses, test_accs, val_losses, val_accs)
        elif val_accs[-1] == best_acc:
            same_accs += 1


print(f"Best LR: {best_lr}, best epochs: {best_epochs}, best val acc: {best_acc:.3f}, best test acc: {best_metrics[3][-1]:.3f}")
print(f"Number of configurations with the same accuracy: {same_accs}")
plot_metrics(*best_metrics)
# Out:
# LR: 0.1, epochs: 100
# Epoch 0: train loss = 0.037 (acc: 0.478), test loss = 0.039 (acc: 0.333),
# val loss = 0.034 (acc: 0.533)
# Epoch 1: train loss = 0.028 (acc: 0.667), test loss = 0.030 (acc: 0.633),
# val loss = 0.027 (acc: 0.667)
# Epoch 2: train loss = 0.025 (acc: 0.667), test loss = 0.023 (acc: 0.733),
# val loss = 0.027 (acc: 0.600)
# Epoch 3: train loss = 0.021 (acc: 0.644), test loss = 0.019 (acc: 0.667),
# val loss = 0.022 (acc: 0.600)
# Epoch 4: train loss = 0.021 (acc: 0.667), test loss = 0.020 (acc: 0.667),
# val loss = 0.020 (acc: 0.667)
# Epoch 5: train loss = 0.016 (acc: 0.678), test loss = 0.016 (acc: 0.667),
# val loss = 0.016 (acc: 0.667)
# Epoch 6: train loss = 0.017 (acc: 0.689), test loss = 0.016 (acc: 0.733),
# val loss = 0.018 (acc: 0.600)
# Epoch 7: train loss = 0.014 (acc: 0.944), test loss = 0.013 (acc: 0.967),
# val loss = 0.015 (acc: 1.000)
# Epoch 8: train loss = 0.015 (acc: 0.667), test loss = 0.015 (acc: 0.667),
# val loss = 0.015 (acc: 0.667)
# Epoch 9: train loss = 0.013 (acc: 0.933), test loss = 0.012 (acc: 0.933),
# val loss = 0.013 (acc: 0.967)
# Epoch 10: train loss = 0.013 (acc: 0.811), test loss = 0.012 (acc: 0.833),
# val loss = 0.014 (acc: 0.767)
# Epoch 11: train loss = 0.012 (acc: 0.956), test loss = 0.011 (acc: 0.933),
# val loss = 0.012 (acc: 0.967)
# Epoch 12: train loss = 0.012 (acc: 0.811), test loss = 0.012 (acc: 0.767),
# val loss = 0.012 (acc: 0.833)
# Epoch 13: train loss = 0.011 (acc: 0.944), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 14: train loss = 0.011 (acc: 0.944), test loss = 0.010 (acc: 0.967),
# val loss = 0.011 (acc: 1.000)
# Epoch 15: train loss = 0.011 (acc: 0.956), test loss = 0.010 (acc: 0.933),
# val loss = 0.011 (acc: 0.967)
# Epoch 16: train loss = 0.011 (acc: 0.911), test loss = 0.010 (acc: 0.900),
# val loss = 0.010 (acc: 0.900)
# Epoch 17: train loss = 0.010 (acc: 0.944), test loss = 0.009 (acc: 0.967),
# val loss = 0.011 (acc: 1.000)
# Epoch 18: train loss = 0.010 (acc: 0.956), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 19: train loss = 0.010 (acc: 0.922), test loss = 0.010 (acc: 0.900),
# val loss = 0.010 (acc: 0.900)
# Epoch 20: train loss = 0.009 (acc: 0.956), test loss = 0.009 (acc: 0.967),
# val loss = 0.009 (acc: 0.967)
# Epoch 21: train loss = 0.009 (acc: 0.944), test loss = 0.009 (acc: 0.967),
# val loss = 0.009 (acc: 1.000)
# Epoch 22: train loss = 0.009 (acc: 0.956), test loss = 0.008 (acc: 1.000),
# val loss = 0.009 (acc: 1.000)
# Epoch 23: train loss = 0.009 (acc: 0.956), test loss = 0.008 (acc: 0.933),
# val loss = 0.008 (acc: 0.967)
# Epoch 24: train loss = 0.008 (acc: 0.956), test loss = 0.008 (acc: 1.000),
# val loss = 0.008 (acc: 1.000)
# Epoch 25: train loss = 0.008 (acc: 0.944), test loss = 0.008 (acc: 1.000),
# val loss = 0.008 (acc: 1.000)
# Epoch 26: train loss = 0.008 (acc: 0.956), test loss = 0.008 (acc: 0.967),
# val loss = 0.008 (acc: 1.000)
# Epoch 27: train loss = 0.008 (acc: 0.956), test loss = 0.008 (acc: 0.933),
# val loss = 0.008 (acc: 0.967)
# Epoch 28: train loss = 0.008 (acc: 0.944), test loss = 0.007 (acc: 1.000),
# val loss = 0.008 (acc: 1.000)
# Epoch 29: train loss = 0.008 (acc: 0.944), test loss = 0.007 (acc: 1.000),
# val loss = 0.007 (acc: 1.000)
# Epoch 30: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 0.933),
# val loss = 0.007 (acc: 0.967)
# Epoch 31: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# val loss = 0.007 (acc: 1.000)
# Epoch 32: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# val loss = 0.007 (acc: 1.000)
# Epoch 33: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 0.967),
# val loss = 0.007 (acc: 0.967)
# Epoch 34: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 1.000)
# Epoch 35: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 1.000)
# Epoch 36: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 1.000)
# Epoch 37: train loss = 0.007 (acc: 0.967), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 0.967)
# Epoch 38: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 1.000)
# Epoch 39: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 1.000)
# Epoch 40: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 1.000)
# Epoch 41: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 0.967),
# val loss = 0.006 (acc: 0.967)
# Epoch 42: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 1.000)
# Epoch 43: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 44: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 45: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 46: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 47: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 0.967)
# Epoch 48: train loss = 0.006 (acc: 0.967), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 49: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 50: train loss = 0.006 (acc: 0.967), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 0.967)
# Epoch 51: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 52: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 53: train loss = 0.005 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 54: train loss = 0.005 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 55: train loss = 0.005 (acc: 0.967), test loss = 0.005 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 56: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 57: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 58: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 59: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 60: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 61: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 62: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 63: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 64: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 65: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 66: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 67: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 68: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 69: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 70: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 71: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 72: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 73: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 74: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 75: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 76: train loss = 0.004 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 77: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 78: train loss = 0.005 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 79: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 80: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 81: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 82: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 83: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 84: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 85: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 86: train loss = 0.004 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 87: train loss = 0.005 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 88: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 89: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 90: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 91: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 92: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 93: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 94: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 95: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 96: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 97: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 98: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 99: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# LR: 0.1, epochs: 200
# Epoch 0: train loss = 0.034 (acc: 0.644), test loss = 0.036 (acc: 0.667),
# val loss = 0.034 (acc: 0.633)
# Epoch 1: train loss = 0.024 (acc: 0.644), test loss = 0.024 (acc: 0.700),
# val loss = 0.025 (acc: 0.567)
# Epoch 2: train loss = 0.019 (acc: 0.878), test loss = 0.018 (acc: 0.867),
# val loss = 0.020 (acc: 0.867)
# Epoch 3: train loss = 0.023 (acc: 0.667), test loss = 0.023 (acc: 0.667),
# val loss = 0.024 (acc: 0.667)
# Epoch 4: train loss = 0.016 (acc: 0.878), test loss = 0.015 (acc: 0.867),
# val loss = 0.017 (acc: 0.900)
# Epoch 5: train loss = 0.017 (acc: 0.667), test loss = 0.015 (acc: 0.733),
# val loss = 0.019 (acc: 0.600)
# Epoch 6: train loss = 0.015 (acc: 0.667), test loss = 0.015 (acc: 0.667),
# val loss = 0.016 (acc: 0.667)
# Epoch 7: train loss = 0.015 (acc: 0.667), test loss = 0.015 (acc: 0.667),
# val loss = 0.016 (acc: 0.667)
# Epoch 8: train loss = 0.014 (acc: 0.733), test loss = 0.013 (acc: 0.733),
# val loss = 0.016 (acc: 0.700)
# Epoch 9: train loss = 0.013 (acc: 0.867), test loss = 0.012 (acc: 0.900),
# val loss = 0.014 (acc: 0.933)
# Epoch 10: train loss = 0.015 (acc: 0.667), test loss = 0.014 (acc: 0.667),
# val loss = 0.015 (acc: 0.667)
# Epoch 11: train loss = 0.012 (acc: 0.933), test loss = 0.011 (acc: 1.000),
# val loss = 0.012 (acc: 0.900)
# Epoch 12: train loss = 0.014 (acc: 0.711), test loss = 0.012 (acc: 0.733),
# val loss = 0.015 (acc: 0.700)
# Epoch 13: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 0.933),
# val loss = 0.011 (acc: 0.900)
# Epoch 14: train loss = 0.011 (acc: 0.878), test loss = 0.010 (acc: 0.867),
# val loss = 0.011 (acc: 0.900)
# Epoch 15: train loss = 0.010 (acc: 0.944), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 16: train loss = 0.010 (acc: 0.956), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 0.967)
# Epoch 17: train loss = 0.010 (acc: 0.956), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 0.967)
# Epoch 18: train loss = 0.009 (acc: 0.944), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 0.967)
# Epoch 19: train loss = 0.009 (acc: 0.944), test loss = 0.009 (acc: 1.000),
# val loss = 0.009 (acc: 1.000)
# Epoch 20: train loss = 0.009 (acc: 0.956), test loss = 0.009 (acc: 1.000),
# val loss = 0.009 (acc: 0.967)
# Epoch 21: train loss = 0.009 (acc: 0.944), test loss = 0.008 (acc: 1.000),
# val loss = 0.009 (acc: 0.967)
# Epoch 22: train loss = 0.009 (acc: 0.944), test loss = 0.008 (acc: 0.967),
# val loss = 0.009 (acc: 0.967)
# Epoch 23: train loss = 0.009 (acc: 0.956), test loss = 0.008 (acc: 1.000),
# val loss = 0.009 (acc: 0.967)
# Epoch 24: train loss = 0.009 (acc: 0.956), test loss = 0.008 (acc: 0.933),
# val loss = 0.009 (acc: 0.967)
# Epoch 25: train loss = 0.009 (acc: 0.911), test loss = 0.008 (acc: 0.900),
# val loss = 0.009 (acc: 0.967)
# Epoch 26: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# val loss = 0.008 (acc: 0.967)
# Epoch 27: train loss = 0.009 (acc: 0.889), test loss = 0.009 (acc: 0.867),
# val loss = 0.009 (acc: 0.867)
# Epoch 28: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# val loss = 0.007 (acc: 0.967)
# Epoch 29: train loss = 0.008 (acc: 0.944), test loss = 0.007 (acc: 0.967),
# val loss = 0.008 (acc: 0.967)
# Epoch 30: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# val loss = 0.007 (acc: 0.967)
# Epoch 31: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# val loss = 0.007 (acc: 0.967)
# Epoch 32: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.007 (acc: 1.000)
# Epoch 33: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.007 (acc: 0.967)
# Epoch 34: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 0.967)
# Epoch 35: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 0.967)
# Epoch 36: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 1.000)
# Epoch 37: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 0.967)
# Epoch 38: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 0.967)
# Epoch 39: train loss = 0.006 (acc: 0.944), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 0.967)
# Epoch 40: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.006 (acc: 0.967)
# Epoch 41: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.006 (acc: 1.000)
# Epoch 42: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.006 (acc: 0.967)
# Epoch 43: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 0.967)
# Epoch 44: train loss = 0.006 (acc: 0.967), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 45: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 0.967)
# Epoch 46: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 0.967)
# Epoch 47: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 48: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 0.967)
# Epoch 49: train loss = 0.005 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 0.967)
# Epoch 50: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 51: train loss = 0.005 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 0.967)
# Epoch 52: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.005 (acc: 0.967)
# Epoch 53: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.005 (acc: 0.967)
# Epoch 54: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.005 (acc: 0.967)
# Epoch 55: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 56: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 57: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 58: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 59: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 60: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 61: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 62: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 63: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 64: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 65: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 66: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 67: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 68: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 69: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 70: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 71: train loss = 0.004 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 72: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 73: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 74: train loss = 0.005 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 75: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 76: train loss = 0.005 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 77: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 78: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 79: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 80: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 81: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 82: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 83: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 84: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 85: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 86: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 87: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 88: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 89: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 90: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 91: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 92: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 93: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 94: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 95: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 96: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 97: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 98: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 99: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 100: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 101: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 102: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 103: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 104: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 105: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 106: train loss = 0.004 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 107: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 108: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 109: train loss = 0.004 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 110: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 111: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 112: train loss = 0.004 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 113: train loss = 0.004 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 114: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 115: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 116: train loss = 0.004 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 117: train loss = 0.004 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 118: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 119: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 120: train loss = 0.004 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 121: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 122: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 123: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 124: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 125: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 126: train loss = 0.004 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 127: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 128: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 129: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 130: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 131: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 132: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 133: train loss = 0.004 (acc: 0.978), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 134: train loss = 0.003 (acc: 0.978), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 135: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 136: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 137: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 138: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 139: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 140: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 141: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 142: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 143: train loss = 0.003 (acc: 0.978), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 144: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 145: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 146: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 147: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 148: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 149: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 150: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 151: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 152: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 153: train loss = 0.003 (acc: 0.978), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 154: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 155: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 156: train loss = 0.003 (acc: 0.978), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 157: train loss = 0.003 (acc: 0.978), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 158: train loss = 0.004 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 159: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 160: train loss = 0.004 (acc: 0.944), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 161: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 162: train loss = 0.004 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 163: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 164: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 165: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 166: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 167: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 168: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 169: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 170: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 171: train loss = 0.003 (acc: 0.978), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 172: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 173: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 174: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 175: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 176: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 177: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 178: train loss = 0.003 (acc: 0.978), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 179: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 180: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 181: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 182: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 183: train loss = 0.004 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 184: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 185: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 186: train loss = 0.003 (acc: 0.978), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 187: train loss = 0.003 (acc: 0.978), test loss = 0.001 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 188: train loss = 0.003 (acc: 0.956), test loss = 0.001 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 189: train loss = 0.003 (acc: 0.967), test loss = 0.001 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 190: train loss = 0.003 (acc: 0.956), test loss = 0.001 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 191: train loss = 0.003 (acc: 0.956), test loss = 0.001 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 192: train loss = 0.003 (acc: 0.978), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 193: train loss = 0.003 (acc: 0.956), test loss = 0.001 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 194: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 195: train loss = 0.003 (acc: 0.978), test loss = 0.001 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 196: train loss = 0.003 (acc: 0.978), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 197: train loss = 0.003 (acc: 0.967), test loss = 0.001 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 198: train loss = 0.003 (acc: 0.967), test loss = 0.001 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 199: train loss = 0.003 (acc: 0.978), test loss = 0.001 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# LR: 0.1, epochs: 500
# Epoch 0: train loss = 0.048 (acc: 0.656), test loss = 0.049 (acc: 0.667),
# val loss = 0.049 (acc: 0.633)
# Epoch 1: train loss = 0.059 (acc: 0.667), test loss = 0.060 (acc: 0.667),
# val loss = 0.060 (acc: 0.667)
# Epoch 2: train loss = 0.029 (acc: 0.667), test loss = 0.028 (acc: 0.667),
# val loss = 0.029 (acc: 0.667)
# Epoch 3: train loss = 0.032 (acc: 0.656), test loss = 0.028 (acc: 0.733),
# val loss = 0.036 (acc: 0.600)
# Epoch 4: train loss = 0.023 (acc: 0.656), test loss = 0.021 (acc: 0.733),
# val loss = 0.025 (acc: 0.600)
# Epoch 5: train loss = 0.021 (acc: 0.667), test loss = 0.021 (acc: 0.667),
# val loss = 0.022 (acc: 0.667)
# Epoch 6: train loss = 0.020 (acc: 0.667), test loss = 0.021 (acc: 0.667),
# val loss = 0.021 (acc: 0.667)
# Epoch 7: train loss = 0.015 (acc: 0.767), test loss = 0.014 (acc: 0.733),
# val loss = 0.016 (acc: 0.767)
# Epoch 8: train loss = 0.017 (acc: 0.667), test loss = 0.015 (acc: 0.733),
# val loss = 0.019 (acc: 0.600)
# Epoch 9: train loss = 0.013 (acc: 0.844), test loss = 0.013 (acc: 0.800),
# val loss = 0.014 (acc: 0.833)
# Epoch 10: train loss = 0.015 (acc: 0.667), test loss = 0.014 (acc: 0.667),
# val loss = 0.015 (acc: 0.667)
# Epoch 11: train loss = 0.012 (acc: 0.956), test loss = 0.011 (acc: 0.967),
# val loss = 0.013 (acc: 0.967)
# Epoch 12: train loss = 0.014 (acc: 0.711), test loss = 0.012 (acc: 0.733),
# val loss = 0.015 (acc: 0.600)
# Epoch 13: train loss = 0.012 (acc: 0.933), test loss = 0.011 (acc: 1.000),
# val loss = 0.012 (acc: 0.967)
# Epoch 14: train loss = 0.013 (acc: 0.722), test loss = 0.012 (acc: 0.733),
# val loss = 0.013 (acc: 0.667)
# Epoch 15: train loss = 0.011 (acc: 0.944), test loss = 0.010 (acc: 0.933),
# val loss = 0.011 (acc: 0.967)
# Epoch 16: train loss = 0.012 (acc: 0.878), test loss = 0.010 (acc: 0.900),
# val loss = 0.012 (acc: 0.933)
# Epoch 17: train loss = 0.010 (acc: 0.956), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 18: train loss = 0.010 (acc: 0.956), test loss = 0.010 (acc: 0.967),
# val loss = 0.010 (acc: 0.967)
# Epoch 19: train loss = 0.010 (acc: 0.956), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 0.967)
# Epoch 20: train loss = 0.010 (acc: 0.956), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 21: train loss = 0.009 (acc: 0.956), test loss = 0.009 (acc: 1.000),
# val loss = 0.009 (acc: 0.967)
# Epoch 22: train loss = 0.009 (acc: 0.967), test loss = 0.009 (acc: 1.000),
# val loss = 0.009 (acc: 0.967)
# Epoch 23: train loss = 0.009 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# val loss = 0.009 (acc: 0.967)
# Epoch 24: train loss = 0.009 (acc: 0.967), test loss = 0.008 (acc: 1.000),
# val loss = 0.009 (acc: 0.967)
# Epoch 25: train loss = 0.009 (acc: 0.956), test loss = 0.008 (acc: 1.000),
# val loss = 0.009 (acc: 1.000)
# Epoch 26: train loss = 0.008 (acc: 0.956), test loss = 0.008 (acc: 1.000),
# val loss = 0.008 (acc: 0.967)
# Epoch 27: train loss = 0.008 (acc: 0.956), test loss = 0.008 (acc: 0.967),
# val loss = 0.008 (acc: 0.967)
# Epoch 28: train loss = 0.008 (acc: 0.956), test loss = 0.008 (acc: 1.000),
# val loss = 0.008 (acc: 1.000)
# Epoch 29: train loss = 0.008 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# val loss = 0.008 (acc: 1.000)
# Epoch 30: train loss = 0.008 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# val loss = 0.008 (acc: 0.967)
# Epoch 31: train loss = 0.008 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# val loss = 0.007 (acc: 0.967)
# Epoch 32: train loss = 0.008 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# val loss = 0.007 (acc: 0.967)
# Epoch 33: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# val loss = 0.007 (acc: 0.967)
# Epoch 34: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# val loss = 0.007 (acc: 0.967)
# Epoch 35: train loss = 0.007 (acc: 0.956), test loss = 0.007 (acc: 1.000),
# val loss = 0.007 (acc: 1.000)
# Epoch 36: train loss = 0.007 (acc: 0.967), test loss = 0.007 (acc: 1.000),
# val loss = 0.007 (acc: 0.967)
# Epoch 37: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.007 (acc: 1.000)
# Epoch 38: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.007 (acc: 0.967)
# Epoch 39: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 1.000)
# Epoch 40: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 1.000)
# Epoch 41: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 1.000)
# Epoch 42: train loss = 0.007 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 0.967)
# Epoch 43: train loss = 0.007 (acc: 0.967), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 1.000)
# Epoch 44: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 1.000)
# Epoch 45: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 0.967)
# Epoch 46: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 1.000)
# Epoch 47: train loss = 0.006 (acc: 0.956), test loss = 0.006 (acc: 1.000),
# val loss = 0.006 (acc: 0.967)
# Epoch 48: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 49: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 50: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 0.967)
# Epoch 51: train loss = 0.006 (acc: 0.967), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 0.967)
# Epoch 52: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 53: train loss = 0.006 (acc: 0.967), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 54: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 0.967),
# val loss = 0.005 (acc: 0.967)
# Epoch 55: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 0.967)
# Epoch 56: train loss = 0.006 (acc: 0.967), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 57: train loss = 0.006 (acc: 0.967), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 58: train loss = 0.006 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 0.967)
# Epoch 59: train loss = 0.005 (acc: 0.967), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 0.967)
# Epoch 60: train loss = 0.005 (acc: 0.956), test loss = 0.005 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 61: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.005 (acc: 1.000)
# Epoch 62: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 63: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 64: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 65: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 66: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 67: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 68: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 69: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 70: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 71: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 72: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 73: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 74: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 75: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 76: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 77: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 78: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 79: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 80: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 81: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 82: train loss = 0.005 (acc: 0.967), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 83: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.004 (acc: 1.000)
# Epoch 84: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 85: train loss = 0.005 (acc: 0.956), test loss = 0.004 (acc: 1.000),
# val loss = 0.004 (acc: 0.967)
# Epoch 86: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 87: train loss = 0.005 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 88: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 89: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 90: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 91: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 92: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 93: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 94: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 95: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 96: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 97: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 98: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 99: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 100: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 101: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 102: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 103: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 104: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 105: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 106: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 107: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 108: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 109: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 110: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 111: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 112: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 113: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 114: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 115: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 116: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 117: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 118: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 119: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 120: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 121: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 122: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 123: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 124: train loss = 0.004 (acc: 0.967), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 125: train loss = 0.004 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 126: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 127: train loss = 0.004 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 128: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 129: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 130: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 131: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 132: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 1.000)
# Epoch 133: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 134: train loss = 0.004 (acc: 0.956), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 135: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 136: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 137: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 138: train loss = 0.004 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 139: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 140: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 141: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 0.967)
# Epoch 142: train loss = 0.004 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 143: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 144: train loss = 0.003 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 145: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 146: train loss = 0.004 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 147: train loss = 0.004 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 148: train loss = 0.004 (acc: 0.967), test loss = 0.002 (acc: 1.000),
# val loss = 0.002 (acc: 1.000)
# Epoch 149: train loss = 0.004 (acc: 0.944), test loss = 0.003 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# Epoch 150: train loss = 0.003 (acc: 0.956), test loss = 0.002 (acc: 1.000),
# val loss = 0.003 (acc: 0.967)
# ...
# val loss = 0.011 (acc: 0.967)
# Epoch 852: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 853: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 854: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 855: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 856: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 857: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 858: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 859: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 860: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 861: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 862: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 863: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 864: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 865: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 866: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 867: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 868: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 869: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 870: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 871: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 872: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 873: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 874: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 875: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 876: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 877: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 878: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 879: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 880: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 881: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 882: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 883: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 884: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 885: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 886: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 887: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 888: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 889: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 890: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 891: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 892: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 893: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 894: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 895: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 896: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 897: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 898: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 899: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 900: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 901: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 902: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 903: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 904: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 905: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 906: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 907: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 908: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 909: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 910: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 911: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 912: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 913: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 914: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 915: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 916: train loss = 0.011 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 917: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 918: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 919: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 920: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 0.967)
# Epoch 921: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 922: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 923: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 924: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.011 (acc: 1.000)
# Epoch 925: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 926: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 927: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 928: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 929: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 930: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 931: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 932: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 0.967)
# Epoch 933: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 0.967)
# Epoch 934: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 935: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 936: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 0.967)
# Epoch 937: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 0.967)
# Epoch 938: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 0.967)
# Epoch 939: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 940: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 941: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 942: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 943: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 944: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 945: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 946: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 947: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 948: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 949: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 950: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 951: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 952: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 953: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 954: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 955: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 956: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 957: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 958: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 959: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 960: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 961: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 962: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 963: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 964: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 965: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 966: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 967: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 968: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 969: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 970: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 971: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 972: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 973: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 974: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 975: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 0.967)
# Epoch 976: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 0.967)
# Epoch 977: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 978: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 979: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 980: train loss = 0.010 (acc: 0.933), test loss = 0.010 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 981: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 982: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 983: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 984: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 985: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 986: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 987: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 988: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 989: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 990: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 991: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 992: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 993: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 994: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 995: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 996: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 997: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 998: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Epoch 999: train loss = 0.010 (acc: 0.933), test loss = 0.009 (acc: 1.000),
# val loss = 0.010 (acc: 1.000)
# Best LR: 0.1, best epochs: 100, best val acc: 1.000, best test acc: 1.000
# Number of configurations with the same accuracy: 9
